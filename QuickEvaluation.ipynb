# %% [markdown]
# #### 0. Prerequisites

# %%
from src.Evaluation.utils import plot_metrics_by_dataset_with_boxplot, significance_test, plot_best_worst_characteristics, get_prerequisits

# %%
# Decide here between the data splitting strategy perfomed in the study ('RO', 'TO')
EVAL_RUN = "RO"
final_eval_df, filtered_model_dict, model_list = get_prerequisits(EVAL_RUN)

# %% [markdown]
# # QuickStart into the Evaluation
# - table with metric results on the test runs
# - box plots for test runs and $10$ "best" / "worst" user's characteristics
# - regression model plots and table with all values $\beta_0, \beta_c, p, \ldots$ is displayed

# %% [markdown]
# ### 1. Display Table with Results

# %%
columns_to_aggregate = [col for col in final_eval_df.columns if col.endswith('@10')]

# Group by "Model" and aggregate those columns using mean
aggregated_df = final_eval_df.groupby('Model')[columns_to_aggregate].mean().reset_index()
aggregated_df.sort_values(by="ndcg@10", ascending=False)
# Out:
#          Model  precision@10    hit@10    mrr@10   ndcg@10    map@10  \
# 0          ALS      0.152966  0.593341  0.329359  0.198749  0.124766
# 8      XSimGCL      0.150149  0.591894  0.329086  0.194740  0.119951
# 2  AsymUserKNN      0.145127  0.583849  0.328943  0.190405  0.117600
# 6          SGL      0.147338  0.583585  0.319677  0.190309  0.116914
# 3          BPR      0.138416  0.577249  0.310411  0.178590  0.106081
# 4     LightGCN      0.134315  0.569503  0.302034  0.173993  0.102587
# 7     UltraGCN      0.133322  0.551415  0.292251  0.172359  0.104095
# 1  AsymItemKNN      0.124047  0.545569  0.193475  0.137902  0.072963
# 5          Pop      0.039420  0.258159  0.096802  0.048425  0.021056
#
#    itemcoverage@10  averagepopularity@10  tailpercentage@10
# 0         0.075893             57.758945           0.000234
# 8         0.120137             51.662866           0.010322
# 2         0.108999             74.511185           0.015634
# 6         0.144644             44.765344           0.011939
# 3         0.080508             73.938899           0.001084
# 4         0.115027             60.163477           0.004301
# 7         0.084255             70.992891           0.001501
# 1         0.130814             46.564064           0.051082
# 5         0.001969            120.488178           0.000000

# %% [markdown]
# ### 2. Show Box-Plots of the Results

# %%
plot_metrics_by_dataset_with_boxplot(final_eval_df,  models_dict=filtered_model_dict, eval_run=EVAL_RUN, metric = "ndcg@10", save_fig = False, with_scatter=True)

# %% [markdown]
# ### 3. Show Box-Plots of the $10$ _best_ / _worst_ User's Characteristics

# %%
characteristics = ['node_degree', 'average_coefficients', 'degree_assort', 'average_popularity']
model = "XSimGCL"
plot_best_worst_characteristics(final_eval_df, model=model, characteristics=characteristics, eval_run=EVAL_RUN, num_datasets=final_eval_df[final_eval_df['Model']==model].shape[0], save_fig=False)
# Out:
# 100%|██████████| 176/176 [00:00<00:00, 13689.34rows/s]
# 100%|██████████| 176/176 [00:00<00:00, 17147.05rows/s]
# 100%|██████████| 176/176 [00:00<00:00, 17061.05rows/s]
# 100%|██████████| 176/176 [00:00<00:00, 17396.37rows/s]

# %% [markdown]
# ### 4. Apply Linear Regression Model
# - dataset characteristics (independent variable) $X_c$
# - target metrics (dependend variabe) $y$
# - influence on target metrics (regression coefficient) $\beta_c$
#
# Model: $y=\beta_0 + \beta_c X_c + e$
#
# where:
#
# - $X_c \equiv \{SpaceSize, Shape, Density, Gini_U, Gini_I, AvgDeg_U, AvgDeg_I, AvgClustC_U, AvgClustC_I, Assort_U, Assort_I\}$
# - $y \equiv \{NDCG@10, IC@10, ARP@10\}$
#
# Null hypothesis: $H_0: \beta_c = 0, \quad H_1: \beta_c \neq 0$
#
# The values of $\beta_c$ are represented by the **bar length**, while the **$p$-value** is indicated by the color.

# %%
# SpaceSize & (Shape or Sparsity) led to strong multicollinearity!
characteristics = {'space_size_log' : '$SpaceSize_{log}$',
                   #'shape' : '$Shape$', 
                   #'sparsity' : '$Sparsity_{log}$',
                   'gini_user' : '$Gini_U$',
                   'gini_item' : '$Gini_I$',
                   'average_degree_user_log' : '$AvgDeg_{U_{log}}$',
                   'average_degree_item_log' : '$AvgDeg_{I_{log}}$',
                   'average_clustering_coef_dot_user_log' : '$AvgClustC_{U_{log}}$',
                   'average_clustering_coef_dot_item_log' : '$AvgClustC_{I_{log}}$',
                   'degree_assort_user' : '$Assort_U$',
                   'degree_assort_item' : '$Assort_I$'
                    }

#### ENTIRE ANALYSIS MODELS ####
models = list(filtered_model_dict.keys())
metrics_dict = {'ndcg' : '$NDCG@10$', 'itemcoverage' : '$IC@10$', 'averagepopularity' : '$ARP@10$', 'tailpercentage' : '$APLT@10$'}

#### Exemplary for Testing ####
models = ["XSimGCL"]
metrics_dict = {'ndcg' : '$NDCG@10$', 'itemcoverage' : '$IC@10$', 'averagepopularity' : '$ARP@10$'}

df_results = significance_test(df=final_eval_df, eval_run = EVAL_RUN,
                               characteristics=characteristics, models=models, metrics=metrics_dict, 
                               transformation="", transform_target="", 
                               save_as_csv=False, create_plots=True, show_plots=True, save_figs=False)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           XSimGCL_ndcg   R-squared:                       0.746
# Model:                            OLS   Adj. R-squared:                  0.733
# Method:                 Least Squares   F-statistic:                     55.10
# Date:                Sun, 16 Feb 2025   Prob (F-statistic):           2.53e-45
# Time:                        10:58:58   Log-Likelihood:                 622.78
# No. Observations:                 176   AIC:                            -1226.
# Df Residuals:                     166   BIC:                            -1194.
# Df Model:                           9
# Covariance Type:                  HC1
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.1947      0.001    356.865      0.000       0.194       0.196
# space_size_log                           0.0845      0.103      0.822      0.411      -0.117       0.286
# gini_user                               -0.1159      0.080     -1.441      0.150      -0.274       0.042
# gini_item                                0.1436      0.112      1.276      0.202      -0.077       0.364
# average_degree_user_log                  0.2100      0.057      3.657      0.000       0.097       0.323
# average_degree_item_log                  0.0603      0.101      0.599      0.549      -0.137       0.258
# average_clustering_coef_dot_user_log     0.2783      0.023     12.313      0.000       0.234       0.323
# average_clustering_coef_dot_item_log     0.0546      0.053      1.039      0.299      -0.048       0.158
# degree_assort_user                      -0.2188      0.037     -5.900      0.000      -0.291      -0.146
# degree_assort_item                      -0.0034      0.003     -0.991      0.322      -0.010       0.003
# ==============================================================================
# Omnibus:                        4.590   Durbin-Watson:                   1.554
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                2.764
# Skew:                           0.070   Prob(JB):                        0.251
# Kurtosis:                       2.402   Cond. No.                         308.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# Parameters:  Intercept                               0.194740
# space_size_log                          0.084458
# gini_user                              -0.115887
# gini_item                               0.143559
# average_degree_user_log                 0.210017
# average_degree_item_log                 0.060302
# average_clustering_coef_dot_user_log    0.278278
# average_clustering_coef_dot_item_log    0.054607
# degree_assort_user                     -0.218764
# degree_assort_item                     -0.003406
# dtype: float64
# R2:  0.7464484549253572
# <class 'pandas.core.series.Series'>
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     XSimGCL_itemcoverage   R-squared:                       0.813
# Model:                              OLS   Adj. R-squared:                  0.803
# Method:                   Least Squares   F-statistic:                     81.25
# Date:                  Sun, 16 Feb 2025   Prob (F-statistic):           3.64e-56
# Time:                          10:58:58   Log-Likelihood:                 660.54
# No. Observations:                   176   AIC:                            -1301.
# Df Residuals:                       166   BIC:                            -1269.
# Df Model:                             9
# Covariance Type:                    HC1
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                                0.1201      0.000    272.845      0.000       0.119       0.121
# space_size_log                           0.1283      0.096      1.330      0.183      -0.061       0.317
# gini_user                               -0.2547      0.060     -4.261      0.000      -0.372      -0.138
# gini_item                                0.1240      0.104      1.187      0.235      -0.081       0.329
# average_degree_user_log                  0.0929      0.046      2.021      0.043       0.003       0.183
# average_degree_item_log                  0.0393      0.100      0.392      0.695      -0.157       0.236
# average_clustering_coef_dot_user_log    -0.0748      0.022     -3.355      0.001      -0.119      -0.031
# average_clustering_coef_dot_item_log    -0.1135      0.050     -2.262      0.024      -0.212      -0.015
# degree_assort_user                       0.0481      0.037      1.310      0.190      -0.024       0.120
# degree_assort_item                       0.0033      0.003      1.149      0.251      -0.002       0.009
# ==============================================================================
# Omnibus:                        0.024   Durbin-Watson:                   1.615
# Prob(Omnibus):                  0.988   Jarque-Bera (JB):                0.084
# Skew:                           0.027   Prob(JB):                        0.959
# Kurtosis:                       2.908   Cond. No.                         308.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# Parameters:  Intercept                               0.120137
# space_size_log                          0.128321
# gini_user                              -0.254662
# gini_item                               0.123965
# average_degree_user_log                 0.092869
# average_degree_item_log                 0.039331
# average_clustering_coef_dot_user_log   -0.074816
# average_clustering_coef_dot_item_log   -0.113484
# degree_assort_user                      0.048061
# degree_assort_item                      0.003259
# dtype: float64
# R2:  0.8134493725511115
# <class 'pandas.core.series.Series'>
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     XSimGCL_averagepopularity   R-squared:                       0.907
# Model:                                   OLS   Adj. R-squared:                  0.902
# Method:                        Least Squares   F-statistic:                     167.0
# Date:                       Sun, 16 Feb 2025   Prob (F-statistic):           2.23e-78
# Time:                               10:58:58   Log-Likelihood:                -466.99
# No. Observations:                        176   AIC:                             954.0
# Df Residuals:                            166   BIC:                             985.7
# Df Model:                                  9
# Covariance Type:                         HC1
# ========================================================================================================
#                                            coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------
# Intercept                               51.6629      0.267    193.698      0.000      51.140      52.186
# space_size_log                        -210.4988     51.656     -4.075      0.000    -311.743    -109.254
# gini_user                               40.6193     34.652      1.172      0.241     -27.297     108.536
# gini_item                              -15.5709     52.642     -0.296      0.767    -118.747      87.605
# average_degree_user_log                -99.5072     25.682     -3.875      0.000    -149.842     -49.172
# average_degree_item_log                153.8715     46.180      3.332      0.001      63.360     244.383
# average_clustering_coef_dot_user_log   104.1428     10.706      9.728      0.000      83.159     125.126
# average_clustering_coef_dot_item_log    43.5422     24.568      1.772      0.076      -4.611      91.695
# degree_assort_user                      48.8960     21.229      2.303      0.021       7.288      90.504
# degree_assort_item                      -0.8635      1.639     -0.527      0.598      -4.076       2.349
# ==============================================================================
# Omnibus:                        5.133   Durbin-Watson:                   1.470
# Prob(Omnibus):                  0.077   Jarque-Bera (JB):                4.791
# Skew:                           0.328   Prob(JB):                       0.0911
# Kurtosis:                       3.472   Cond. No.                         308.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
# Parameters:  Intercept                                51.662866
# space_size_log                         -210.498785
# gini_user                                40.619314
# gini_item                               -15.570908
# average_degree_user_log                 -99.507239
# average_degree_item_log                 153.871525
# average_clustering_coef_dot_user_log    104.142785
# average_clustering_coef_dot_item_log     43.542227
# degree_assort_user                       48.896023
# degree_assort_item                       -0.863541
# dtype: float64
# R2:  0.90734452816476
# <class 'pandas.core.series.Series'>

# %%
df_results
# Out:
#      model             metric     score  adjusted_score  Intercept  \
# 0  XSimGCL               ndcg  0.746448        0.732702   0.194740
# 1  XSimGCL       itemcoverage  0.813449        0.803335   0.120137
# 2  XSimGCL  averagepopularity  0.907345        0.902321  51.662866
#
#    space_size_log  gini_user  gini_item  average_degree_user_log  \
# 0        0.084458  -0.115887   0.143559                 0.210017
# 1        0.128321  -0.254662   0.123965                 0.092869
# 2     -210.498785  40.619314 -15.570908               -99.507239
#
#    average_degree_item_log  ...  p_Intercept  p_space_size_log  p_gini_user  \
# 0                 0.060302  ...          0.0          0.410971     0.149701
# 1                 0.039331  ...          0.0          0.183388     0.000020
# 2               153.871525  ...          0.0          0.000046     0.241111
#
#    p_gini_item  p_average_degree_user_log  p_average_degree_item_log  \
# 0     0.201853                   0.000255                   0.549191
# 1     0.235197                   0.043243                   0.695036
# 2     0.767391                   0.000107                   0.000862
#
#    p_average_clustering_coef_dot_user_log  \
# 0                            7.698876e-35
# 1                            7.934472e-04
# 2                            2.301042e-22
#
#    p_average_clustering_coef_dot_item_log  p_degree_assort_user  \
# 0                                0.298930          3.641884e-09
# 1                                0.023724          1.900954e-01
# 2                                0.076344          2.126476e-02
#
#    p_degree_assort_item
# 0              0.321627
# 1              0.250558
# 2              0.598277
#
# [3 rows x 24 columns]
