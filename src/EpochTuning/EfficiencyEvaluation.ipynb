# %% [markdown]
# ## Evaluate Epoch Tuning
#
# - use `{Model}-RandomSearch-{EVAL_RUN}.csv` to plot number of epochs against target metric ($NDCG$) and $loss$

# %%
from utils import plot_training_results

# %% [markdown]
# ### 1. Generate Plots among multiple Algorithms

# %%
EVAL_RUN = "RO"

log_files = {
    "ALS": f"ALS-RandomSearch-{EVAL_RUN}.txt",
    "BPR": "BPR-RandomSearch-RO.txt",
    "UltraGCN": f"UltraGCN-RandomSearch-{EVAL_RUN}.txt",
    "SGL": "SGL-RandomSearch-RO.txt",
    "XSimGCL": f"XSimGCL-RandomSearch-{EVAL_RUN}.txt"
}

plot_training_results(
    log_files=log_files,
    plot_mean=True,
    plot_ndgc_alone=True,
    line_width=2,
    save_fig=False
)

# %%
log_files = {
    "ALS": f"ALS-RandomSearch-{EVAL_RUN}.txt",
}

plot_training_results(
    log_files=log_files,
    plot_mean=False,
    plot_ndgc_alone=False,
    line_width=2,
    save_fig=False
)

# %%
log_files = {
    "BPR": "BPR-RandomSearch-RO.txt",
}

plot_training_results(
    log_files=log_files,
    plot_mean=False,
    plot_ndgc_alone=False,
    line_width=2,
    save_fig=False
)

# %%
log_files = {
    "LightGCN": f"LightGCN-RandomSearch-RO.txt",
}

plot_training_results(
    log_files=log_files,
    plot_mean=False,
    plot_ndgc_alone=False,
    line_width=2,
    save_fig=False
)

# %%
log_files = {
    "UltraGCN": f"UltraGCN-RandomSearch-{EVAL_RUN}.txt",
}

plot_training_results(
    log_files=log_files,
    plot_mean=False,
    plot_ndgc_alone=False,
    line_width=2,
    save_fig=False
)

# %%
log_files = {
    "SGL": f"SGL-RandomSearch-RO.txt",
}

plot_training_results(
    log_files=log_files,
    plot_mean=False,
    plot_ndgc_alone=False,
    line_width=2,
    save_fig=False
)

# %%
log_files = {
    "XSimGCL": f"XSimGCL-RandomSearch-{EVAL_RUN}.txt",
}

plot_training_results(
    log_files=log_files,
    plot_mean=False,
    plot_ndgc_alone=False,
    line_width=2,
    save_fig=False
)
